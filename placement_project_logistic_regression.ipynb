# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/placement.csv')
data
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
data.info
# Out:
# <bound method DataFrame.info of     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]>

# %%
df=data.iloc[:,1:]

# %%
df
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
x=df.iloc[:,:2]
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y=df.iloc[:,-1]
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 30   7.6  128.0
# 8    6.1  156.0
# 73   4.9   61.0
# 46   5.3  114.0
# 89   4.9  151.0
# ..   ...    ...
# 71   6.1  132.0
# 76   4.9  155.0
# 3    7.4  132.0
# 17   3.3  183.0
# 21   7.1  151.0
#
# [90 rows x 2 columns]

# %%
x_test
# Out:
#     cgpa     iq
# 25   5.0   91.0
# 14   6.1  103.0
# 33   6.0  149.0
# 91   7.5  158.0
# 22   4.9  120.0
# 59   4.8  112.0
# 32   7.0  139.0
# 41   5.4  114.0
# 50   3.5  233.0
# 98   6.3  103.0

# %%
y_test
# Out:
# 25    0
# 14    0
# 33    0
# 91    1
# 22    0
# 59    0
# 32    1
# 41    0
# 50    0
# 98    1
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 1.38504763,  0.13553731],
#        [ 0.06268957,  0.84122744],
#        [-0.99519688, -1.55307836],
#        [-0.64256806, -0.21730776],
#        [-0.99519688,  0.71521135],
#        [-0.55441086,  0.41277272],
#        [ 0.32716118,  0.46317916],
#        [-1.08335408,  0.46317916],
#        [-1.17151129, -0.04088522],
#        [ 1.38504763, -0.84738823],
#        [ 1.29689042,  0.18594375],
#        [ 0.8561044 , -0.26771419],
#        [ 0.59163279,  0.79082101],
#        [ 0.67979   ,  0.00952122],
#        [-1.78861172, -1.2002333 ],
#        [-0.90703968, -1.50267193],
#        [-0.73072527,  0.96724354],
#        [-0.64256806, -0.04088522],
#        [ 0.23900398,  0.13553731],
#        [ 0.67979   , -0.26771419],
#        [ 1.56136204, -0.21730776],
#        [-0.73072527,  2.55504634],
#        [ 0.94426161, -1.88072021],
#        [ 0.06268957, -1.04901398],
#        [-0.55441086,  0.31195984],
#        [ 0.41531838,  0.94204032],
#        [ 1.73767644, -1.09942042],
#        [ 0.8561044 ,  1.92496586],
#        [ 1.12057602,  0.36236628],
#        [-0.73072527, -0.82218501],
#        [-1.25966849,  0.58919525],
#        [-1.17151129, -1.77990734],
#        [-0.73072527,  0.23635019],
#        [-0.55441086, -0.39373029],
#        [-0.81888247,  1.34529183],
#        [ 2.00214806,  1.14366607],
#        [-1.08335408,  1.01764998],
#        [-1.08335408,  1.16886929],
#        [ 0.8561044 , -1.47746871],
#        [ 0.50347559,  0.3875695 ],
#        [-0.28993925,  0.5135856 ],
#        [ 0.41531838, -0.82218501],
#        [-0.28993925,  1.16886929],
#        [ 1.29689042, -1.55307836],
#        [-0.81888247, -1.42706227],
#        [ 0.67979   ,  0.46317916],
#        [ 0.8561044 ,  1.32008861],
#        [ 1.12057602, -0.92299789],
#        [-0.20178204,  1.09325963],
#        [ 0.7679472 ,  0.41277272],
#        [-0.11362484, -0.41893351],
#        [-0.02546764, -1.95632987],
#        [ 0.50347559, -0.06608844],
#        [ 0.23900398,  0.11033409],
#        [-0.28993925,  0.43797594],
#        [-1.78861172, -0.57015282],
#        [-0.20178204,  0.48838238],
#        [ 0.32716118, -0.16690132],
#        [-1.4359829 ,  0.66480491],
#        [-0.28993925,  0.23635019],
#        [-0.02546764, -0.51974638],
#        [ 0.41531838, -2.15795562],
#        [ 0.15084677, -0.24251097],
#        [-0.02546764, -1.42706227],
#        [ 0.7679472 ,  0.3875695 ],
#        [-0.99519688,  0.28675663],
#        [-1.5241401 ,  1.95016908],
#        [ 1.82583365,  0.66480491],
#        [-0.73072527, -0.31812063],
#        [ 1.12057602, -1.83031377],
#        [ 1.12057602, -0.16690132],
#        [-1.87676892, -0.34332385],
#        [-1.4359829 , -2.03193953],
#        [ 2.17846246, -0.06608844],
#        [-0.02546764,  0.03472444],
#        [ 0.06268957, -1.45226549],
#        [-0.81888247,  0.13553731],
#        [ 1.82583365,  1.09325963],
#        [-0.99519688,  1.84935621],
#        [ 0.59163279,  1.49651114],
#        [ 0.7679472 , -0.6709657 ],
#        [ 0.41531838,  0.18594375],
#        [-0.90703968, -0.11649488],
#        [ 0.67979   , -0.82218501],
#        [-1.17151129, -0.89779467],
#        [ 0.06268957,  0.23635019],
#        [-0.99519688,  0.81602423],
#        [ 1.20873322,  0.23635019],
#        [-2.40571214,  1.52171436],
#        [ 0.94426161,  0.71521135]])

# %%
x_test=scaler.transform(x_test)

# %%
x_test
# Out:
# array([[-0.90703968, -0.79698179],
#        [ 0.06268957, -0.49454316],
#        [-0.02546764,  0.66480491],
#        [ 1.29689042,  0.89163388],
#        [-0.99519688, -0.06608844],
#        [-1.08335408, -0.26771419],
#        [ 0.8561044 ,  0.41277272],
#        [-0.55441086, -0.21730776],
#        [-2.22939774,  2.78187531],
#        [ 0.23900398, -0.49454316]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
# model training
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
clf.predict(x_test)
# Out:
# array([0, 1, 1, 1, 0, 0, 1, 0, 0, 1])

# %%
y_pred= clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8

# %%
from mlxtend.plotting import plot_decision_regions

# %%
# plotting decision Boundry
plot_decision_regions(x_train, y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
